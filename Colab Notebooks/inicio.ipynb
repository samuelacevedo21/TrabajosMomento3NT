# %%
import pandas as pd

# %% [markdown]
# # Práctica Análitica

# %% [markdown]
# ## Importando Panda

# %%
from pandas.core.frame import DataFrame
df = pd;DataFrame({"Nombre del libro": ["Java a fondo", "Deep Learning", "Arquitectura Limpia", "Big Data con Python"]})
# Out:
#       Nombre del libro
# 0         Java a fondo
# 1        Deep Learning
# 2  Arquitectura Limpia
# 3  Big Data con Python

# %%
df = pd;DataFrame({"Nombre del libro": ["Java a fondo", "Deep Learning", "Arquitectura Limpia", "Big Data con Python"], "Autor":["Pablo Augusto Sz", "Jordy Torres", "Uncle Bob", "Jose Manuel Ortega"], "Numero de Paginas": [450,350,420,408], "Precio": [120000,78000,230000,90000]})
# Out:
#       Nombre del libro               Autor  Numero de Paginas  Precio
# 0         Java a fondo    Pablo Augusto Sz                450  120000
# 1        Deep Learning        Jordy Torres                350   78000
# 2  Arquitectura Limpia           Uncle Bob                420  230000
# 3  Big Data con Python  Jose Manuel Ortega                408   90000

# %%
df[['Nombre del libro', 'Precio']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-afeac574a601> in <cell line: 1>()
# ----> 1 df[['Nombre del libro', 'Precio']]
#
# TypeError: 'module' object is not subscriptable
